# %%
import pandas as pd
student_classes = {
    'Karteek': 'C#',
    'Sowjanya':'Java',
    'Madhuri': 'Python',
    'Kiran': 'Jenkins'
}

# %%
s = pd.Series(student_classes)

# %%
s.iloc[3]
# Out:
# 'Jenkins'

# %%
s.loc['Karteek']
# Out:
# 'C#'

# %%
s[3]
# Out:
# 'Jenkins'

# %%
s['Karteek']
# Out:
# 'C#'

# %%
s[1:2]
# Out:
# Sowjanya    Java
# dtype: object

# %%
s[1:]
# Out:
# Sowjanya       Java
# Madhuri      Python
# Kiran       Jenkins
# dtype: object

# %%
class_code = {
    99: 'C#',
    100: 'Java',
    101: 'Python',
    102: 'Jenkins'
}

# %%
s = pd.Series(class_code)

# %%
s
# Out:
# 99          C#
# 100       Java
# 101     Python
# 102    Jenkins
# dtype: object

# %%
s.iloc[0]
# Out:
# 'C#'

# %%
grades = pd.Series([90,80,70,60])

# %%
total = 0
for grade in grades:
    total+=grade
print (total/len(grades))
# Out:
# 75.0

# %%
import numpy as np

# %%
total = np.sum(grades)

# %%
total/len(grades)
# Out:
# 75.0

# %%
np.average(grades)
# Out:
# 75.0

# %%
numbers = pd.Series(np.random.randint(0,1000,10000))

# %%
numbers.head()
# Out:
# 0    116
# 1    812
# 2    576
# 3    892
# 4    484
# dtype: int64

# %%
len(numbers)
# Out:
# 10000

# %%
# %%timeit -n 10000
total = 0
for grade in grades:
    total+=grade
print (total/len(grades))
# Out:
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# ...

# %%
# %%timeit -n 10000
total/len(grades)
# Out:
# 1.1 µs ± 109 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
numbers.head()
# Out:
# 0    116
# 1    812
# 2    576
# 3    892
# 4    484
# dtype: int64

# %%
numbers += 2

# %%
numbers.head()
# Out:
# 0    118
# 1    814
# 2    578
# 3    894
# 4    486
# dtype: int64

# %%
for label, value in numbers.iteritems():
    numbers.iat(label,value+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f1784e752427> in <module>
#       1 for label, value in numbers.iteritems():
# ----> 2     numbers.iat(label,value+2)
#
# TypeError: '_iAtIndexer' object is not callable

# %%
s = pd.Series([1,2,3])

# %%
s.loc['C#'] = 102

# %%
s
# Out:
# 0       1
# 1       2
# 2       3
# C#    102
# dtype: int64

# %%
s = pd.Series(student_classes)
s
# Out:
# Karteek          C#
# Sowjanya       Java
# Madhuri      Python
# Kiran       Jenkins
# dtype: object

# %%
sowmi_classes = pd.Series(['Math','Science','Social'], index = ['Sowmi','Sowmi','Sowmi'])

# %%
sowmi_classes
# Out:
# Sowmi       Math
# Sowmi    Science
# Sowmi     Social
# dtype: object

# %%
all_student = s.append(sowmi_classes)

# %%
all_student
# Out:
# Karteek          C#
# Sowjanya       Java
# Madhuri      Python
# Kiran       Jenkins
# Sowmi          Math
# Sowmi       Science
# Sowmi        Social
# dtype: object

# %%
s
# Out:
# Karteek          C#
# Sowjanya       Java
# Madhuri      Python
# Kiran       Jenkins
# dtype: object

# %%
all_student.loc['Sowmi']
# Out:
# Sowmi       Math
# Sowmi    Science
# Sowmi     Social
# dtype: object
